# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure
import numpy as np
import pandas as pd
import bokeh.charts as bok

# %%
df = pd.read_excel('ratio.xlsx')
df.columns.values[0] = 'ratio'
df.columns
colooms = df['ratio']

# %%
df = df.iloc[:, 1:].transpose()
df.columns = colooms.values
df.head()
# Out:
#       Afghanistan  Albania  Algeria  American Samoa  Andorra  Angola  \
# 1960          NaN      NaN      NaN             NaN      NaN     NaN
# 1961          NaN      NaN      NaN             NaN      NaN     NaN
# 1962          NaN      NaN      NaN             NaN      NaN     NaN
# 1963          NaN      NaN      NaN             NaN      NaN     NaN
# 1964          NaN      NaN      NaN             NaN      NaN     NaN
#
#       Antigua and Barbuda  Argentina  Armenia  Aruba    ...     Uruguay  \
# 1960                  NaN        NaN      NaN    NaN    ...         NaN
# 1961                  NaN        NaN      NaN    NaN    ...         NaN
# 1962                  NaN        NaN      NaN    NaN    ...         NaN
# 1963                  NaN        NaN      NaN    NaN    ...         NaN
# 1964                  NaN        NaN      NaN    NaN    ...         NaN
#
#       Uzbekistan  Vanuatu  Venezuela  Vietnam  Virgin Islands (U.S.)  \
# ...

# %%
print(df.columns.values.size)
print(df.dropna(how='all', axis='columns').columns.values.size)

# %%
# Out:
# 213
# 155

# %%
output_notebook()
plot = figure()

plot.circle(df['incomeperperson'], df['alcconsumption'], size=3)

show(plot)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="782763e1-e750-472a-a136-fbfb04af55a6">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="581247ba-6323-40b4-9498-43299233fbd4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
# ...

# %%
df.head()
# Out:
#                  country  incomeperperson  alcconsumption  armedforcesrate  \
# 0    ANTARCTIC FISHERIES              NaN             NaN              NaN
# 1               Abkhazia              NaN             NaN              NaN
# 2            Afghanistan              NaN            0.03         0.569653
# 3  Akrotiri and Dhekelia              NaN             NaN              NaN
# 4                Albania      1914.996551            7.29         1.024736
#
#    breastcancerper100th  co2emissions  femaleemployrate  hivrate  \
# 0                   NaN  1.430000e+05               NaN      NaN
# 1                   NaN           NaN               NaN      NaN
# 2                  26.8  7.594400e+07         25.600000      NaN
# 3                   NaN           NaN               NaN      NaN
# 4                  57.4  2.237473e+08         42.099998      NaN
#
#    internetuserate  lifeexpectancy  oilperperson  polityscore  \
# ...

# %%
! pwd
# Out:
# /Users/dlemaire/dpl/data_analytics_course
